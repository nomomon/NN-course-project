# %%
from ase.db import connect

# %%
train_db = connect("./data/train.db")

# %%
for row in train_db.select():
    print(row)
    pass
# Out:
# <AtomsRow: formula=C17H20N4O2S, keys=>
# <AtomsRow: formula=C17H20N4O2S, keys=>
# <AtomsRow: formula=C17H20N4O2S, keys=>
# <AtomsRow: formula=C17H20N4O2S, keys=>
# <AtomsRow: formula=C14H22N4O3S, keys=>
# <AtomsRow: formula=C14H22N4O3S, keys=>
# <AtomsRow: formula=C14H22N4O3S, keys=>
# <AtomsRow: formula=C14H22N4O3S, keys=>
# <AtomsRow: formula=C12H16N4O2S, keys=>
# <AtomsRow: formula=C12H16N4O2S, keys=>
# <AtomsRow: formula=C13H18N4O2S, keys=>
# <AtomsRow: formula=C13H18N4O2S, keys=>
# <AtomsRow: formula=C13H18N4O2S, keys=>
# <AtomsRow: formula=C13H18N4O2S, keys=>
# <AtomsRow: formula=C12H16N4O3S, keys=>
# <AtomsRow: formula=C20H26N2O3, keys=>
# <AtomsRow: formula=C20H26N2O3, keys=>
# <AtomsRow: formula=C20H26N2O3, keys=>
# <AtomsRow: formula=C20H26N2O3, keys=>
# <AtomsRow: formula=C20H26N2O3, keys=>
# <AtomsRow: formula=C20H26N2O3, keys=>
# <AtomsRow: formula=C20H26N2O3, keys=>
# <AtomsRow: formula=C20H26N2O3, keys=>
# <AtomsRow: formula=C20H26N2O3, keys=>
# ...

# %%
# !pip
